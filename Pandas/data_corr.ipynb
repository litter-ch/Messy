# %%
# 数据相关性
import pandas as pd
df = pd.read_csv('data/scores.csv') # 导入csv数据
df1 = df[['数学','英语','物理']]  # 选择指定列
df1.corr()
# Out:
#           数学        英语        物理
# 数学  1.000000 -0.275400  0.075893
# 英语 -0.275400  1.000000 -0.663266
# 物理  0.075893 -0.663266  1.000000

# %%
df = pd.read_csv('data/data.csv')
# 计算相关性矩阵
# correlation_matrix = df.corr()    # method默认为pearson 皮尔逊相关系数
# print(correlation_matrix)
# 计算皮尔逊相关系数
correlation = df.corr(method='pearson')
print(correlation)
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.155408  0.009403  0.922717
# Pulse    -0.155408  1.000000  0.786535  0.025121
# Maxpulse  0.009403  0.786535  1.000000  0.203813
# Calories  0.922717  0.025121  0.203813  1.000000

# %%
# 计算斯皮尔曼等级相关系数
spearman_correlation = df.corr(method='spearman')
print(spearman_correlation)
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.158436 -0.068517  0.815127
# Pulse    -0.158436  1.000000  0.788520  0.186022
# Maxpulse -0.068517  0.788520  1.000000  0.271928
# Calories  0.815127  0.186022  0.271928  1.000000

# %%
# 计算肯德尔秩相关系数
kendall_correlation = df.corr(method='kendall')
print(kendall_correlation)
# Out:
#           Duration     Pulse  Maxpulse  Calories
# Duration  1.000000 -0.124808 -0.046464  0.687394
# Pulse    -0.124808  1.000000  0.640451  0.158295
# Maxpulse -0.046464  0.640451  1.000000  0.198774
# Calories  0.687394  0.158295  0.198774  1.000000

# %%
# 相关性热图（Correlation Heatmap）
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
# 绘制相关性热图
plt.figure(figsize=(8, 6))
# sns.heatmap() 绘制相关性热图
# annot=True 表示在热图上显示数值
# cmap='RdBu' 设置颜色范围
# vmin=-1, vmax=1 限制颜色范围为 -1 到 1
sns.heatmap(df.corr(), annot=True, cmap='Blues_r', fmt='.2f', vmin=-1, vmax=12)
plt.title('Correlation Heatmap')
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 设置主题和颜色调色板
sns.set_theme(style="whitegrid", palette="pastel")
# 示例数据
products = ["Product A", "Product B", "Product C", "Product D"]
sales = [120, 210, 150, 180]

# 创建柱状图
sns.barplot(x=products, y=sales)

# 添加标签和标题
plt.xlabel("Products")
plt.ylabel("Sales")
plt.title("Product Sales by Category")

# 显示图表
plt.show()
